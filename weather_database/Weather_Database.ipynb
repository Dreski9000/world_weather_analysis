# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longtitue combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
city_names = set([citipy.nearest_city(coordinate[0], coordinate[1]).city_name for coordinate in coordinates])
city_names
# Out:
# {'abong mbang',
#  'acapulco',
#  'acarau',
#  'adre',
#  'afanasyevo',
#  'aflu',
#  'airai',
#  'aklavik',
#  'albany',
#  'alice springs',
#  'alofi',
#  'along',
#  'alta floresta',
#  'altamira',
#  'alto araguaia',
#  'ambilobe',
#  'amderma',
#  'anadyr',
#  'ancona',
#  'ancud',
#  'anito',
#  'antalaha',
#  'antofagasta',
#  'aqtobe',
#  'arlit',
#  'arman',
#  'arraial do cabo',
#  'artyshta',
#  'atar',
#  'athabasca',
#  'attawapiskat',
#  'atuona',
#  'auki',
#  'avarua',
#  'avera',
#  'babylon',
#  'baculin',
#  'baishishan',
#  'bako',
#  'ballater',
#  'bambanglipuro',
#  'bambous virieux',
#  'banda aceh',
#  'bandarbeyla',
#  'banepa',
#  'banff',
#  'baoma',
#  'barawe',
#  'barentsburg',
#  'barrow',
#  'bathsheba',
#  'bavly',
#  'beberibe',
#  'bektemir',
#  'belushya guba',
#  'bengkulu',
#  'berbera',
#  'bereda',
#  'berlevag',
#  'betare oya',
#  'bethel',
#  'bilibino',
#  'bilma',
#  'bluff',
#  'bolgatanga',
#  'bontang',
#  'bousso',
#  'bozoum',
#  'bra',
#  'bredasdorp',
#  'brive-la-gaillarde',
#  'broome',
#  'buala',
#  'bubaque',
#  'buchmany',
#  'bumba',
#  'bundaberg',
#  'buraydah',
#  'busselton',
#  'butaritari',
#  'byron bay',
#  'cabedelo',
#  'cabinda',
#  'cabo san lucas',
#  'cairns',
#  'camacha',
#  'campbell river',
#  'cape town',
#  'caravelas',
#  'carmelo',
#  'carnarvon',
#  'castanos',
#  'castro',
#  'cayenne',
#  'cazones',
#  'chapais',
#  'chara',
#  'charagua',
#  'chastoozerye',
#  'cherskiy',
#  'chingirlau',
#  'chokurdakh',
#  'christchurch',
#  'chumikan',
#  'chuy',
#  'cidreira',
#  'ciudad ojeda',
#  'clarence town',
#  'clyde river',
#  'cockburn town',
#  'coffs harbour',
#  'coihaique',
#  'college',
#  'comodoro rivadavia',
#  'concordia',
#  'conde',
#  'constitucion',
#  'coquimbo',
#  'cotonou',
#  'cowra',
#  'cozumel',
#  'danielskuil',
#  'darhan',
#  'den helder',
#  'dengzhou',
#  'denpasar',
#  'dharchula',
#  'dickinson',
#  'dien bien',
#  'dikson',
#  'dingle',
#  'dolbeau',
#  'dolinsk',
#  'dong xoai',
#  'dongsheng',
#  'dosso',
#  'douglas',
#  'dzhusaly',
#  'east london',
#  'el centro',
#  'elizabeth city',
#  'emerald',
#  'erzin',
#  'erzurum',
#  'eslamshahr',
#  'esperance',
#  'estelle',
#  'ewa beach',
#  'eyl',
#  'faanui',
#  'fare',
#  'fargo',
#  'fengrun',
#  'fernandina beach',
#  'flin flon',
#  'flinders',
#  'fort nelson',
#  'fort-shevchenko',
#  'fortuna',
#  'fuxin',
#  'galgani',
#  'gamba',
#  'gandajika',
#  'gaoua',
#  'gat',
#  'georgetown',
#  'geraldton',
#  'goderich',
#  'goundam',
#  'grand centre',
#  'grand river south east',
#  'grindavik',
#  'guerrero negro',
#  'gumla',
#  'guru har sahai',
#  'haibowan',
#  'haines junction',
#  'hakkari',
#  'haldwani',
#  'hami',
#  'harfleur',
#  'harper',
#  'harriston',
#  'hasaki',
#  'hearst',
#  'henderson',
#  'hermanus',
#  'hihifo',
#  'hilo',
#  'hithadhoo',
#  'ho',
#  'hobart',
#  'hobyo',
#  'hofn',
#  'homa bay',
#  'houma',
#  'hovd',
#  'hualmay',
#  'huarmey',
#  'husavik',
#  'ilebo',
#  'illoqqortoormiut',
#  'ilulissat',
#  'imbituba',
#  'inuvik',
#  'iqaluit',
#  'isangel',
#  'itarema',
#  'ixtapa',
#  'jamestown',
#  'jati',
#  'jawhar',
#  'jiblah',
#  'jiuquan',
#  'juifang',
#  'jumla',
#  'kaeo',
#  'kahului',
#  'kaitangata',
#  'kamaishi',
#  'kamenskoye',
#  'kamiiso',
#  'kangaatsiaq',
#  'kapaa',
#  'kapit',
#  'karamay',
#  'karasburg',
#  'kardamaina',
#  'karpogory',
#  'kasama',
#  'kasongo-lunda',
#  'katherine',
#  'kathmandu',
#  'kavaratti',
#  'kavieng',
#  'kenai',
#  'ketchikan',
#  'khandyga',
#  'khani',
#  'kharp',
#  'khatanga',
#  'kholodnyy',
#  'khonuu',
#  'khor',
#  'kibakwe',
#  'kimbe',
#  'kinango',
#  'kirakira',
#  'kiruna',
#  'kitimat',
#  'klaksvik',
#  'kodiak',
#  'komsomolets',
#  'komsomolskiy',
#  'korla',
#  'kovdor',
#  'krasnoslobodsk',
#  'kruisfontein',
#  'ksenyevka',
#  'kulebaki',
#  'kununurra',
#  'kushima',
#  'kysyl-syr',
#  'la palma',
#  'la paz centro',
#  'la plaine',
#  'la ronge',
#  'labuhan',
#  'labutta',
#  'lagoa',
#  'laguna',
#  'lake havasu city',
#  'laramie',
#  'lata',
#  'laukaa',
#  'lavrentiya',
#  'laza',
#  'lebu',
#  'leningradskiy',
#  'lethem',
#  'liepaja',
#  'linchuan',
#  'linhares',
#  'llanes',
#  'locri',
#  'lolua',
#  'longyearbyen',
#  'lorengau',
#  'los llanos de aridane',
#  'louga',
#  'luanda',
#  'luderitz',
#  'luganville',
#  'luoyang',
#  'lusaka',
#  'maarianhamina',
#  'macaboboni',
#  'mahasamund',
#  'mahebourg',
#  'malwan',
#  'mana',
#  'mananjary',
#  'mandalgovi',
#  'mangrol',
#  'manicore',
#  'manokwari',
#  'mao',
#  'mar del plata',
#  'maragogi',
#  'marcona',
#  'margate',
#  'marv dasht',
#  'marzuq',
#  'mashivka',
#  'mataura',
#  'maumere',
#  'mayo',
#  'mehamn',
#  'mehriz',
#  'mering',
#  'meulaboh',
#  'milevsko',
#  'minab',
#  'mineros',
#  'miranda',
#  'monte alegre de minas',
#  'montepulciano',
#  'morgan city',
#  'morondava',
#  'morwa',
#  'mosquera',
#  'mount isa',
#  'moussoro',
#  'mpanda',
#  'mrirt',
#  'mufulira',
#  'mumford',
#  'murgab',
#  'muros',
#  'mutsamudu',
#  'mys shmidta',
#  'nakamura',
#  'nalut',
#  'namibe',
#  'nampula',
#  'nanakuli',
#  'nanortalik',
#  'narsaq',
#  'naze',
#  'neiafu',
#  'nelson bay',
#  'nevelsk',
#  'new norfolk',
#  'ngukurr',
#  'nikolskoye',
#  'nioro',
#  'nipawin',
#  'nishihara',
#  'nizhneyansk',
#  'nizhniy kuranakh',
#  'nizhniy odes',
#  'nokaneng',
#  'nome',
#  'norman wells',
#  'norwich',
#  'noshiro',
#  'nouakchott',
#  'noumea',
#  'novikovo',
#  'novyy urgal',
#  'nurota',
#  'nuuk',
#  'nyuksenitsa',
#  'nyurba',
#  'ocara',
#  'okandja',
#  'oktyabrskiy',
#  'olafsvik',
#  'olenino',
#  'omaruru',
#  'ondangwa',
#  'oranjemund',
#  'ormara',
#  'oshawa',
#  'ossora',
#  'ostersund',
#  'osypenko',
#  'otkaznoye',
#  'pacific grove',
#  'padang',
#  'pafos',
#  'pahrump',
#  'palamos',
#  'palanga',
#  'palmer',
#  'pamanukan',
#  'pampierstad',
#  'panalingaan',
#  'pangnirtung',
#  'paraiso',
#  'parrita',
#  'pasighat',
#  'pauini',
#  'payo',
#  'pemangkat',
#  'pevek',
#  'pisco',
#  'plettenberg bay',
#  'ponta delgada',
#  'ponta do sol',
#  'porac',
#  'port alfred',
#  'port augusta',
#  'port elizabeth',
#  'port hardy',
#  'port hedland',
#  'port lincoln',
#  'port moresby',
#  'porteirinha',
#  'portland',
#  'porto seguro',
#  'porto velho',
#  'poso',
#  'potiskum',
#  'poum',
#  'povenets',
#  'poya',
#  'poyarkovo',
#  'praia',
#  'praya',
#  'prince rupert',
#  'provideniya',
#  'puerto ayora',
#  'puerto colombia',
#  'puerto del rosario',
#  'puerto leguizamo',
#  'puerto maldonado',
#  'punta arenas',
#  'puri',
#  'qaanaaq',
#  'qarayeri',
#  'qena',
#  'quatre cocos',
#  'quelimane',
#  'qui nhon',
#  'rabo de peixe',
#  'rafiganj',
#  'rapid city',
#  'rawson',
#  'raya',
#  'rehoboth',
#  'riaba',
#  'ribeira grande',
#  'richards bay',
#  'rikitea',
#  'riyadh',
#  'road town',
#  'roald',
#  'roros',
#  'rudbar',
#  'ruteng',
#  'saguing',
#  'saiha',
#  'saint anthony',
#  'saint george',
#  'saint-ambroise',
#  'saint-augustin',
#  'saint-francois',
#  'saint-philippe',
#  'saint-pierre',
#  'salalah',
#  'salamina',
#  'saldanha',
#  'salinopolis',
#  'salisbury',
#  'salto',
#  'samarai',
#  'sambava',
#  'samusu',
#  'san carlos de bariloche',
#  'san cristobal',
#  'san pablo',
#  'san patricio',
#  'san quintin',
#  'san rafael del sur',
#  'san vicente',
#  'santa cruz del norte',
#  'santa vitoria do palmar',
#  'santiago',
#  'sao filipe',
#  'sao joao da barra',
#  'sao joao da ponte',
#  'saskylakh',
#  'satitoa',
#  'savannah bight',
#  'saverne',
#  'sayyan',
#  'scarborough',
#  'scottsbluff',
#  'sentyabrskiy',
#  'sept-iles',
#  'sereflikochisar',
#  'severnyy',
#  'severo-kurilsk',
#  'severomuysk',
#  'shangrao',
#  'shelburne',
#  'shimoda',
#  'shirokiy',
#  'sibolga',
#  'sibu',
#  'sigli',
#  'sindand',
#  'sindgi',
#  'sinnamary',
#  'sioux lookout',
#  'sitka',
#  'slavutych',
#  'sobolevo',
#  'sogdiondon',
#  'sola',
#  'songjianghe',
#  'sorong',
#  'soubre',
#  'souillac',
#  'south lake tahoe',
#  'soyo',
#  'sparta',
#  'srednekolymsk',
#  'staryy nadym',
#  'storforshei',
#  'stykkisholmur',
#  'sumter',
#  'sungaipenuh',
#  'suntar',
#  'svatove',
#  'svetlaya',
#  'taksimo',
#  'talara',
#  'talaya',
#  'talnakh',
#  'tanjong karang',
#  'taolanaro',
#  'tasiilaq',
#  'tautira',
#  'tawzar',
#  'tazmalt',
#  'te anau',
#  'teguise',
#  'terme',
#  'ternate',
#  'terney',
#  'teseney',
#  'tessalit',
#  'thayetmyo',
#  'the valley',
#  'thompson',
#  'tibati',
#  'tigre',
#  'tiksi',
#  'tilichiki',
#  'timizart',
#  'tiznit',
#  'tocopilla',
#  'tomatlan',
#  'torbay',
#  'touros',
#  'troitskoye',
#  'tsihombe',
#  'tual',
#  'tuburan',
#  'tukrah',
#  'tuktoyaktuk',
#  'tumannyy',
#  'tunga',
#  'tuni',
#  'turukhansk',
#  'ubon ratchathani',
#  'ulaangom',
#  'ulety',
#  'umm jarr',
#  'umm lajj',
#  'uniao da victoria',
#  'upernavik',
#  'urfa',
#  'ushuaia',
#  'vaini',
#  'vaitupu',
#  'vakhsh',
#  'vanimo',
#  'vao',
#  'vardo',
#  'varhaug',
#  'veracruz',
#  'verdalsora',
#  'verkh-chebula',
#  'verkhoyansk',
#  'vestmanna',
#  'victoria',
#  'vila',
#  'vila franca do campo',
#  'viligili',
#  'villa rica',
#  'virginia beach',
#  'vitim',
#  'vorukh',
#  'vostok',
#  'voyvozh',
#  'wagar',
#  'wahran',
#  'wakkanai',
#  'wanaka',
#  'warqla',
#  'warwick',
#  'wenatchee',
#  'wenling',
#  'westport',
#  'whitehorse',
#  'wonthaggi',
#  'wundanyi',
#  'yablonovo',
#  'yar-sale',
#  'yellowknife',
#  'yeppoon',
#  'yulara',
#  'yunjinghong',
#  'zaranj',
#  'zhanatas',
#  'zhangye',
#  'zinder',
#  'zlatoustovsk',
#  'znamenskoye',
#  'zyryanka'}

# %%
len(city_names)
# Out:
# 633

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_1 = url + "&q=" + list(city_names)[0].replace(" ", "+")
print(city_1)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b9f90ebca398970ed9d24ddfd796d2a5&q=nyuksenitsa

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(city_names):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_weather_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nyuksenitsa
# Processing Record 2 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 3 of Set 1 | tilichiki
# Processing Record 4 of Set 1 | vardo
# Processing Record 5 of Set 1 | nioro
# Processing Record 6 of Set 1 | artyshta
# Processing Record 7 of Set 1 | tigre
# Processing Record 8 of Set 1 | tazmalt
# Processing Record 9 of Set 1 | vao
# Processing Record 10 of Set 1 | milevsko
# Processing Record 11 of Set 1 | riaba
# City not found. Skipping...
# Processing Record 12 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 1 | portland
# Processing Record 14 of Set 1 | coffs harbour
# Processing Record 15 of Set 1 | antalaha
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 1 | dong xoai
# Processing Record 20 of Set 1 | rapid city
# Processing Record 21 of Set 1 | laza
# Processing Record 22 of Set 1 | faanui
# Processing Record 23 of Set 1 | harper
# Processing Record 24 of Set 1 | yulara
# Processing Record 25 of Set 1 | zinder
# Processing Record 26 of Set 1 | luganville
# Processing Record 27 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | bavly
# Processing Record 30 of Set 1 | tukrah
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | ambilobe
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | miranda
# Processing Record 35 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 1 | south lake tahoe
# Processing Record 37 of Set 1 | stykkisholmur
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | ponta delgada
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | mosquera
# Processing Record 42 of Set 1 | ormara
# Processing Record 43 of Set 1 | rabo de peixe
# Processing Record 44 of Set 1 | savannah bight
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | sindand
# City not found. Skipping...
# Processing Record 47 of Set 1 | saint-francois
# Processing Record 48 of Set 1 | chara
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | shelburne
# Processing Record 1 of Set 2 | linchuan
# City not found. Skipping...
# Processing Record 2 of Set 2 | brive-la-gaillarde
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | san rafael del sur
# Processing Record 5 of Set 2 | prince rupert
# Processing Record 6 of Set 2 | camacha
# Processing Record 7 of Set 2 | pampierstad
# Processing Record 8 of Set 2 | bako
# Processing Record 9 of Set 2 | gamba
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | sioux lookout
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | moussoro
# Processing Record 14 of Set 2 | bumba
# Processing Record 15 of Set 2 | wundanyi
# Processing Record 16 of Set 2 | carmelo
# Processing Record 17 of Set 2 | uniao da victoria
# City not found. Skipping...
# Processing Record 18 of Set 2 | morwa
# Processing Record 19 of Set 2 | guru har sahai
# Processing Record 20 of Set 2 | timizart
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | voyvozh
# Processing Record 23 of Set 2 | thompson
# Processing Record 24 of Set 2 | bilibino
# Processing Record 25 of Set 2 | mangrol
# Processing Record 26 of Set 2 | cockburn town
# Processing Record 27 of Set 2 | bengkulu
# Processing Record 28 of Set 2 | saint-augustin
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 2 | songjianghe
# Processing Record 32 of Set 2 | harriston
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | jumla
# Processing Record 35 of Set 2 | harfleur
# Processing Record 36 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | mpanda
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | arman
# Processing Record 41 of Set 2 | villa rica
# Processing Record 42 of Set 2 | saguing
# Processing Record 43 of Set 2 | vila franca do campo
# Processing Record 44 of Set 2 | poum
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | acapulco
# Processing Record 47 of Set 2 | karasburg
# Processing Record 48 of Set 2 | monte alegre de minas
# Processing Record 49 of Set 2 | santiago
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | mufulira
# Processing Record 2 of Set 3 | berbera
# Processing Record 3 of Set 3 | palamos
# Processing Record 4 of Set 3 | gat
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | sibolga
# Processing Record 8 of Set 3 | bubaque
# Processing Record 9 of Set 3 | mehriz
# Processing Record 10 of Set 3 | minab
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | fargo
# Processing Record 13 of Set 3 | tanjong karang
# City not found. Skipping...
# Processing Record 14 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 3 | atar
# Processing Record 16 of Set 3 | santa cruz del norte
# Processing Record 17 of Set 3 | pahrump
# Processing Record 18 of Set 3 | chingirlau
# Processing Record 19 of Set 3 | tawzar
# City not found. Skipping...
# Processing Record 20 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 3 | san vicente
# Processing Record 22 of Set 3 | sao joao da ponte
# Processing Record 23 of Set 3 | praya
# Processing Record 24 of Set 3 | erzin
# Processing Record 25 of Set 3 | coihaique
# Processing Record 26 of Set 3 | mandalgovi
# Processing Record 27 of Set 3 | fuxin
# Processing Record 28 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 29 of Set 3 | murgab
# Processing Record 30 of Set 3 | gandajika
# Processing Record 31 of Set 3 | bra
# Processing Record 32 of Set 3 | eslamshahr
# Processing Record 33 of Set 3 | leningradskiy
# Processing Record 34 of Set 3 | berlevag
# Processing Record 35 of Set 3 | zyryanka
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | louga
# Processing Record 38 of Set 3 | el centro
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | porac
# Processing Record 41 of Set 3 | taksimo
# Processing Record 42 of Set 3 | cowra
# Processing Record 43 of Set 3 | srednekolymsk
# Processing Record 44 of Set 3 | aklavik
# Processing Record 45 of Set 3 | saint george
# Processing Record 46 of Set 3 | yar-sale
# Processing Record 47 of Set 3 | panalingaan
# Processing Record 48 of Set 3 | veracruz
# Processing Record 49 of Set 3 | ksenyevka
# City not found. Skipping...
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | ilebo
# Processing Record 2 of Set 4 | banff
# Processing Record 3 of Set 4 | baoma
# Processing Record 4 of Set 4 | komsomolskiy
# Processing Record 5 of Set 4 | baishishan
# Processing Record 6 of Set 4 | quatre cocos
# Processing Record 7 of Set 4 | severomuysk
# Processing Record 8 of Set 4 | emerald
# Processing Record 9 of Set 4 | cotonou
# Processing Record 10 of Set 4 | morondava
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | bozoum
# Processing Record 13 of Set 4 | beberibe
# Processing Record 14 of Set 4 | roald
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | qui nhon
# Processing Record 17 of Set 4 | huarmey
# Processing Record 18 of Set 4 | kenai
# Processing Record 19 of Set 4 | novikovo
# Processing Record 20 of Set 4 | rehoboth
# Processing Record 21 of Set 4 | sungaipenuh
# Processing Record 22 of Set 4 | whitehorse
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | nevelsk
# Processing Record 25 of Set 4 | ruteng
# Processing Record 26 of Set 4 | ketchikan
# Processing Record 27 of Set 4 | neiafu
# Processing Record 28 of Set 4 | mataura
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | morgan city
# Processing Record 31 of Set 4 | buraydah
# Processing Record 32 of Set 4 | avera
# Processing Record 33 of Set 4 | bredasdorp
# Processing Record 34 of Set 4 | zaranj
# Processing Record 35 of Set 4 | sereflikochisar
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 4 | torbay
# Processing Record 39 of Set 4 | mount isa
# Processing Record 40 of Set 4 | adre
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | mineros
# Processing Record 43 of Set 4 | tuktoyaktuk
# Processing Record 44 of Set 4 | bontang
# Processing Record 45 of Set 4 | naze
# Processing Record 46 of Set 4 | terme
# Processing Record 47 of Set 4 | ballater
# Processing Record 48 of Set 4 | kangaatsiaq
# Processing Record 49 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 4 | antofagasta
# Processing Record 1 of Set 5 | san carlos de bariloche
# Processing Record 2 of Set 5 | lusaka
# Processing Record 3 of Set 5 | praia
# Processing Record 4 of Set 5 | nanortalik
# Processing Record 5 of Set 5 | fernandina beach
# Processing Record 6 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 5 | umm lajj
# Processing Record 8 of Set 5 | mering
# Processing Record 9 of Set 5 | vorukh
# Processing Record 10 of Set 5 | virginia beach
# Processing Record 11 of Set 5 | pemangkat
# Processing Record 12 of Set 5 | barrow
# Processing Record 13 of Set 5 | margate
# Processing Record 14 of Set 5 | port moresby
# Processing Record 15 of Set 5 | kushima
# Processing Record 16 of Set 5 | los llanos de aridane
# Processing Record 17 of Set 5 | acarau
# Processing Record 18 of Set 5 | mahasamund
# Processing Record 19 of Set 5 | nouakchott
# Processing Record 20 of Set 5 | roros
# Processing Record 21 of Set 5 | llanes
# Processing Record 22 of Set 5 | comodoro rivadavia
# Processing Record 23 of Set 5 | dengzhou
# Processing Record 24 of Set 5 | salamina
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | mumford
# Processing Record 28 of Set 5 | labuhan
# Processing Record 29 of Set 5 | marzuq
# Processing Record 30 of Set 5 | gumla
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | chuy
# Processing Record 33 of Set 5 | tual
# Processing Record 34 of Set 5 | ewa beach
# Processing Record 35 of Set 5 | sindgi
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | laramie
# Processing Record 38 of Set 5 | karpogory
# Processing Record 39 of Set 5 | soyo
# Processing Record 40 of Set 5 | albany
# Processing Record 41 of Set 5 | noshiro
# Processing Record 42 of Set 5 | pauini
# Processing Record 43 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 5 | san quintin
# Processing Record 45 of Set 5 | khandyga
# Processing Record 46 of Set 5 | lebu
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | bluff
# Processing Record 50 of Set 5 | dickinson
# Processing Record 1 of Set 6 | ondangwa
# Processing Record 2 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 3 of Set 6 | hearst
# Processing Record 4 of Set 6 | tomatlan
# Processing Record 5 of Set 6 | arraial do cabo
# Processing Record 6 of Set 6 | pangnirtung
# Processing Record 7 of Set 6 | the valley
# Processing Record 8 of Set 6 | grindavik
# Processing Record 9 of Set 6 | flinders
# Processing Record 10 of Set 6 | vila
# Processing Record 11 of Set 6 | punta arenas
# Processing Record 12 of Set 6 | lake havasu city
# Processing Record 13 of Set 6 | lorengau
# Processing Record 14 of Set 6 | otkaznoye
# Processing Record 15 of Set 6 | kardamaina
# Processing Record 16 of Set 6 | samarai
# Processing Record 17 of Set 6 | riyadh
# Processing Record 18 of Set 6 | sept-iles
# Processing Record 19 of Set 6 | san pablo
# Processing Record 20 of Set 6 | sao filipe
# Processing Record 21 of Set 6 | ossora
# Processing Record 22 of Set 6 | namibe
# Processing Record 23 of Set 6 | puerto maldonado
# Processing Record 24 of Set 6 | mao
# Processing Record 25 of Set 6 | ostersund
# Processing Record 26 of Set 6 | nizhniy odes
# Processing Record 27 of Set 6 | noumea
# Processing Record 28 of Set 6 | sparta
# Processing Record 29 of Set 6 | bundaberg
# Processing Record 30 of Set 6 | broome
# Processing Record 31 of Set 6 | qena
# Processing Record 32 of Set 6 | itarema
# Processing Record 33 of Set 6 | chumikan
# Processing Record 34 of Set 6 | hofn
# Processing Record 35 of Set 6 | buala
# Processing Record 36 of Set 6 | manokwari
# Processing Record 37 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 39 of Set 6 | hovd
# Processing Record 40 of Set 6 | rikitea
# Processing Record 41 of Set 6 | shirokiy
# Processing Record 42 of Set 6 | mahebourg
# Processing Record 43 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 6 | tiznit
# Processing Record 45 of Set 6 | kysyl-syr
# Processing Record 46 of Set 6 | bilma
# Processing Record 47 of Set 6 | vanimo
# Processing Record 48 of Set 6 | verkh-chebula
# Processing Record 49 of Set 6 | vostok
# Processing Record 50 of Set 6 | goundam
# Processing Record 1 of Set 7 | vakhsh
# Processing Record 2 of Set 7 | olafsvik
# Processing Record 3 of Set 7 | coquimbo
# Processing Record 4 of Set 7 | ribeira grande
# Processing Record 5 of Set 7 | husavik
# Processing Record 6 of Set 7 | svatove
# Processing Record 7 of Set 7 | nizhniy kuranakh
# Processing Record 8 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 7 | salisbury
# Processing Record 10 of Set 7 | dosso
# Processing Record 11 of Set 7 | puri
# Processing Record 12 of Set 7 | teseney
# Processing Record 13 of Set 7 | arlit
# Processing Record 14 of Set 7 | talara
# Processing Record 15 of Set 7 | auki
# Processing Record 16 of Set 7 | slavutych
# Processing Record 17 of Set 7 | banepa
# Processing Record 18 of Set 7 | tessalit
# Processing Record 19 of Set 7 | sambava
# Processing Record 20 of Set 7 | oktyabrskiy
# Processing Record 21 of Set 7 | kaitangata
# Processing Record 22 of Set 7 | anito
# Processing Record 23 of Set 7 | kamaishi
# Processing Record 24 of Set 7 | kununurra
# Processing Record 25 of Set 7 | wakkanai
# Processing Record 26 of Set 7 | shimoda
# Processing Record 27 of Set 7 | kasama
# Processing Record 28 of Set 7 | westport
# Processing Record 29 of Set 7 | port augusta
# Processing Record 30 of Set 7 | osypenko
# Processing Record 31 of Set 7 | nalut
# Processing Record 32 of Set 7 | inuvik
# Processing Record 33 of Set 7 | fort nelson
# Processing Record 34 of Set 7 | pisco
# Processing Record 35 of Set 7 | wanaka
# Processing Record 36 of Set 7 | haines junction
# Processing Record 37 of Set 7 | tuburan
# Processing Record 38 of Set 7 | along
# Processing Record 39 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 40 of Set 7 | sao joao da barra
# Processing Record 41 of Set 7 | clarence town
# Processing Record 42 of Set 7 | verkhoyansk
# Processing Record 43 of Set 7 | geraldton
# Processing Record 44 of Set 7 | campbell river
# Processing Record 45 of Set 7 | puerto ayora
# Processing Record 46 of Set 7 | sumter
# Processing Record 47 of Set 7 | conde
# Processing Record 48 of Set 7 | maarianhamina
# Processing Record 49 of Set 7 | staryy nadym
# Processing Record 50 of Set 7 | saint anthony
# Processing Record 1 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 8 | anadyr
# Processing Record 3 of Set 8 | paraiso
# Processing Record 4 of Set 8 | porto seguro
# Processing Record 5 of Set 8 | new norfolk
# Processing Record 6 of Set 8 | potiskum
# Processing Record 7 of Set 8 | korla
# Processing Record 8 of Set 8 | homa bay
# Processing Record 9 of Set 8 | banda aceh
# Processing Record 10 of Set 8 | danielskuil
# Processing Record 11 of Set 8 | tuni
# Processing Record 12 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 8 | eyl
# Processing Record 14 of Set 8 | dongsheng
# Processing Record 15 of Set 8 | nelson bay
# Processing Record 16 of Set 8 | parrita
# Processing Record 17 of Set 8 | richards bay
# Processing Record 18 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 19 of Set 8 | pafos
# Processing Record 20 of Set 8 | tautira
# Processing Record 21 of Set 8 | jiblah
# Processing Record 22 of Set 8 | locri
# Processing Record 23 of Set 8 | te anau
# Processing Record 24 of Set 8 | byron bay
# Processing Record 25 of Set 8 | porto velho
# Processing Record 26 of Set 8 | wagar
# Processing Record 27 of Set 8 | liepaja
# Processing Record 28 of Set 8 | castanos
# Processing Record 29 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 8 | qarayeri
# Processing Record 31 of Set 8 | tibati
# Processing Record 32 of Set 8 | ulety
# Processing Record 33 of Set 8 | montepulciano
# Processing Record 34 of Set 8 | santa vitoria do palmar
# Processing Record 35 of Set 8 | isangel
# Processing Record 36 of Set 8 | meulaboh
# Processing Record 37 of Set 8 | dikson
# Processing Record 38 of Set 8 | baculin
# Processing Record 39 of Set 8 | gaoua
# Processing Record 40 of Set 8 | cabedelo
# Processing Record 41 of Set 8 | imbituba
# Processing Record 42 of Set 8 | bousso
# Processing Record 43 of Set 8 | houma
# Processing Record 44 of Set 8 | cabinda
# Processing Record 45 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 8 | tunga
# Processing Record 47 of Set 8 | afanasyevo
# City not found. Skipping...
# Processing Record 48 of Set 8 | kharp
# Processing Record 49 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 50 of Set 8 | luanda
# Processing Record 1 of Set 9 | constitucion
# Processing Record 2 of Set 9 | ulaangom
# Processing Record 3 of Set 9 | palmer
# Processing Record 4 of Set 9 | bolgatanga
# Processing Record 5 of Set 9 | vitim
# Processing Record 6 of Set 9 | nakamura
# Processing Record 7 of Set 9 | nuuk
# Processing Record 8 of Set 9 | henderson
# Processing Record 9 of Set 9 | nurota
# Processing Record 10 of Set 9 | bandarbeyla
# Processing Record 11 of Set 9 | mayo
# Processing Record 12 of Set 9 | kibakwe
# Processing Record 13 of Set 9 | ho
# City not found. Skipping...
# Processing Record 14 of Set 9 | georgetown
# Processing Record 15 of Set 9 | poya
# Processing Record 16 of Set 9 | sorong
# Processing Record 17 of Set 9 | plettenberg bay
# Processing Record 18 of Set 9 | kirakira
# Processing Record 19 of Set 9 | babylon
# Processing Record 20 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 9 | nokaneng
# Processing Record 22 of Set 9 | hakkari
# Processing Record 23 of Set 9 | kahului
# Processing Record 24 of Set 9 | narsaq
# Processing Record 25 of Set 9 | puerto colombia
# Processing Record 26 of Set 9 | nishihara
# Processing Record 27 of Set 9 | verdalsora
# City not found. Skipping...
# Processing Record 28 of Set 9 | lata
# Processing Record 29 of Set 9 | nipawin
# Processing Record 30 of Set 9 | kinango
# Processing Record 31 of Set 9 | douglas
# Processing Record 32 of Set 9 | omaruru
# Processing Record 33 of Set 9 | oranjemund
# Processing Record 34 of Set 9 | yellowknife
# Processing Record 35 of Set 9 | goderich
# Processing Record 36 of Set 9 | road town
# Processing Record 37 of Set 9 | jawhar
# Processing Record 38 of Set 9 | kathmandu
# Processing Record 39 of Set 9 | norman wells
# Processing Record 40 of Set 9 | den helder
# Processing Record 41 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 42 of Set 9 | krasnoslobodsk
# Processing Record 43 of Set 9 | la plaine
# Processing Record 44 of Set 9 | mehamn
# Processing Record 45 of Set 9 | thayetmyo
# Processing Record 46 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 9 | sola
# Processing Record 48 of Set 9 | alice springs
# Processing Record 49 of Set 9 | nome
# Processing Record 50 of Set 9 | oshawa
# Processing Record 1 of Set 10 | busselton
# Processing Record 2 of Set 10 | rafiganj
# Processing Record 3 of Set 10 | kavieng
# Processing Record 4 of Set 10 | bathsheba
# Processing Record 5 of Set 10 | ilulissat
# Processing Record 6 of Set 10 | znamenskoye
# Processing Record 7 of Set 10 | ocara
# Processing Record 8 of Set 10 | yeppoon
# Processing Record 9 of Set 10 | port alfred
# Processing Record 10 of Set 10 | flin flon
# Processing Record 11 of Set 10 | laguna
# Processing Record 12 of Set 10 | port hardy
# Processing Record 13 of Set 10 | kimbe
# Processing Record 14 of Set 10 | talaya
# Processing Record 15 of Set 10 | alto araguaia
# Processing Record 16 of Set 10 | salto
# Processing Record 17 of Set 10 | khor
# Processing Record 18 of Set 10 | saverne
# Processing Record 19 of Set 10 | tasiilaq
# Processing Record 20 of Set 10 | linhares
# Processing Record 21 of Set 10 | mana
# Processing Record 22 of Set 10 | turukhansk
# Processing Record 23 of Set 10 | sitka
# Processing Record 24 of Set 10 | soubre
# Processing Record 25 of Set 10 | pacific grove
# Processing Record 26 of Set 10 | manicore
# Processing Record 27 of Set 10 | fort-shevchenko
# Processing Record 28 of Set 10 | troitskoye
# Processing Record 29 of Set 10 | scottsbluff
# Processing Record 30 of Set 10 | cairns
# Processing Record 31 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 10 | bereda
# Processing Record 33 of Set 10 | raya
# Processing Record 34 of Set 10 | scarborough
# Processing Record 35 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 10 | sibu
# Processing Record 37 of Set 10 | saint-ambroise
# Processing Record 38 of Set 10 | altamira
# Processing Record 39 of Set 10 | ancona
# Processing Record 40 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 10 | teguise
# Processing Record 42 of Set 10 | khani
# Processing Record 43 of Set 10 | provideniya
# Processing Record 44 of Set 10 | guerrero negro
# Processing Record 45 of Set 10 | la palma
# Processing Record 46 of Set 10 | hermanus
# Processing Record 47 of Set 10 | castro
# Processing Record 48 of Set 10 | storforshei
# Processing Record 49 of Set 10 | rudbar
# Processing Record 50 of Set 10 | kruisfontein
# Processing Record 1 of Set 11 | puerto del rosario
# Processing Record 2 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 11 | aqtobe
# Processing Record 4 of Set 11 | kovdor
# Processing Record 5 of Set 11 | sogdiondon
# City not found. Skipping...
# Processing Record 6 of Set 11 | hualmay
# Processing Record 7 of Set 11 | ubon ratchathani
# Processing Record 8 of Set 11 | wenatchee
# Processing Record 9 of Set 11 | fare
# Processing Record 10 of Set 11 | betare oya
# Processing Record 11 of Set 11 | jati
# Processing Record 12 of Set 11 | dingle
# Processing Record 13 of Set 11 | pamanukan
# Processing Record 14 of Set 11 | port hedland
# Processing Record 15 of Set 11 | saint-pierre
# Processing Record 16 of Set 11 | concordia
# Processing Record 17 of Set 11 | katherine
# Processing Record 18 of Set 11 | mashivka
# Processing Record 19 of Set 11 | maumere
# Processing Record 20 of Set 11 | christchurch
# Processing Record 21 of Set 11 | kasongo-lunda
# Processing Record 22 of Set 11 | ciudad ojeda
# Processing Record 23 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 11 | varhaug
# Processing Record 25 of Set 11 | vaini
# Processing Record 26 of Set 11 | erzurum
# Processing Record 27 of Set 11 | palanga
# Processing Record 28 of Set 11 | warwick
# Processing Record 29 of Set 11 | mananjary
# Processing Record 30 of Set 11 | kulebaki
# Processing Record 31 of Set 11 | kaeo
# Processing Record 32 of Set 11 | kiruna
# Processing Record 33 of Set 11 | sinnamary
# Processing Record 34 of Set 11 | bektemir
# Processing Record 35 of Set 11 | povenets
# Processing Record 36 of Set 11 | wenling
# Processing Record 37 of Set 11 | talnakh
# Processing Record 38 of Set 11 | suntar
# Processing Record 39 of Set 11 | cazones
# Processing Record 40 of Set 11 | padang
# Processing Record 41 of Set 11 | saiha
# Processing Record 42 of Set 11 | komsomolets
# Processing Record 43 of Set 11 | san cristobal
# Processing Record 44 of Set 11 | bambous virieux
# Processing Record 45 of Set 11 | quelimane
# Processing Record 46 of Set 11 | tocopilla
# Processing Record 47 of Set 11 | maragogi
# Processing Record 48 of Set 11 | luderitz
# Processing Record 49 of Set 11 | denpasar
# Processing Record 50 of Set 11 | kitimat
# Processing Record 1 of Set 12 | dharchula
# Processing Record 2 of Set 12 | nampula
# Processing Record 3 of Set 12 | la paz centro
# Processing Record 4 of Set 12 | buchmany
# Processing Record 5 of Set 12 | saskylakh
# Processing Record 6 of Set 12 | la ronge
# Processing Record 7 of Set 12 | estelle
# Processing Record 8 of Set 12 | bambanglipuro
# Processing Record 9 of Set 12 | haldwani
# Processing Record 10 of Set 12 | puerto leguizamo
# Processing Record 11 of Set 12 | wonthaggi
# Processing Record 12 of Set 12 | terney
# Processing Record 13 of Set 12 | hami
# Processing Record 14 of Set 12 | darhan
# Processing Record 15 of Set 12 | fengrun
# Processing Record 16 of Set 12 | alofi
# Processing Record 17 of Set 12 | kavaratti
# Processing Record 18 of Set 12 | rawson
# Processing Record 19 of Set 12 | ternate
# Processing Record 20 of Set 12 | zhangye
# Processing Record 21 of Set 12 | nyurba
# Processing Record 22 of Set 12 | elizabeth city
# Processing Record 23 of Set 12 | novyy urgal
# Processing Record 24 of Set 12 | laukaa
# Processing Record 25 of Set 12 | nanakuli
# Processing Record 26 of Set 12 | vestmanna
# Processing Record 27 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 12 | sigli
# Processing Record 29 of Set 12 | norwich
# Processing Record 30 of Set 12 | poyarkovo
# Processing Record 31 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 12 | sobolevo
# Processing Record 33 of Set 12 | lagoa
# Processing Record 34 of Set 12 | payo
# Processing Record 35 of Set 12 | chapais
# Processing Record 36 of Set 12 | chokurdakh
# Processing Record 37 of Set 12 | cayenne
# Processing Record 38 of Set 12 | abong mbang
# Processing Record 39 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 12 | urfa
# City not found. Skipping...
# Processing Record 41 of Set 12 | kapit
# Processing Record 42 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 12 | hobyo
# Processing Record 44 of Set 12 | qaanaaq
# Processing Record 45 of Set 12 | charagua
# Processing Record 46 of Set 12 | sayyan
# Processing Record 47 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 48 of Set 12 | dolinsk
# Processing Record 49 of Set 12 | lethem
# Processing Record 50 of Set 12 | hithadhoo
# Processing Record 1 of Set 13 | salalah
# Processing Record 2 of Set 13 | porteirinha
# Processing Record 3 of Set 13 | athabasca
# Processing Record 4 of Set 13 | saint-philippe
# Processing Record 5 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 6 of Set 13 | jiuquan
# Processing Record 7 of Set 13 | souillac
# Processing Record 8 of Set 13 | kholodnyy
# Processing Record 9 of Set 13 | severo-kurilsk
# Processing Record 10 of Set 13 | olenino
# Processing Record 11 of Set 13 | yablonovo
# Processing Record 12 of Set 13 | pasighat
# Processing Record 13 of Set 13 | shangrao
# Processing Record 14 of Set 13 | clyde river
# Processing Record 15 of Set 13 | airai
# Processing Record 16 of Set 13 | severnyy
# Processing Record 17 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 13 | salinopolis
# Processing Record 19 of Set 13 | caravelas
# Processing Record 20 of Set 13 | kamiiso
# Processing Record 21 of Set 13 | butaritari
# Processing Record 22 of Set 13 | poso
# Processing Record 23 of Set 13 | muros
# Processing Record 24 of Set 13 | ixtapa
# Processing Record 25 of Set 13 | ponta do sol
# Processing Record 26 of Set 13 | hasaki
# Processing Record 27 of Set 13 | alta floresta
# Processing Record 28 of Set 13 | avarua
# Processing Record 29 of Set 13 | chastoozerye
# City not found. Skipping...
# Processing Record 30 of Set 13 | luoyang
# Processing Record 31 of Set 13 | svetlaya
# Processing Record 32 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 13 | cozumel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 575

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Nyuksenitsa  60.4128   44.2397     -2.25       100          70        4.21
# 1    Tilichiki  60.4667  166.1000     -4.72        79           1        8.61
# 2        Vardo  70.3705   31.1107     23.14        82          59       20.94
# 3        Nioro  13.3500  -15.7500     73.80        34           0        2.44
# 4     Artyshta  54.1222   86.2909      7.54        86         100        3.24
#
#   Country                 Date      Description
# 0      RU  2022-02-07 02:50:40    broken clouds
# 1      RU  2022-02-07 02:50:41        clear sky
# 2      NO  2022-02-07 02:50:41    broken clouds
# 3      GM  2022-02-07 02:50:42        clear sky
# 4      RU  2022-02-07 02:50:42  overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
test_df = pd.read_csv("weather_database/WeatherPy_Database.csv")
test_df.describe()
# Out:
#           City_ID         Lat         Lng    Max Temp    Humidity  Cloudiness  \
# count  575.000000  575.000000  575.000000  575.000000  575.000000  575.000000
# mean   287.000000   20.613958   18.832387   49.185948   73.937391   56.346087
# std    166.132477   32.599071   90.523038   30.530434   21.154968   41.395983
# min      0.000000  -54.800000 -175.200000  -39.730000   11.000000    0.000000
# 25%    143.500000   -6.416100  -59.656750   29.905000   66.000000    8.000000
# 50%    287.000000   25.208800   22.266700   59.610000   79.000000   71.000000
# 75%    430.500000   47.945850   99.557300   74.050000   89.500000  100.000000
# max    574.000000   78.218600  178.416700   92.710000  100.000000  100.000000
#
#        Wind Speed
# count  575.000000
# mean     7.796261
# std      6.726442
# min      0.000000
# 25%      3.240000
# 50%      6.040000
# 75%     10.650000
# max     60.310000
